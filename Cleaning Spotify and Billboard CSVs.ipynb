# %%
# Dependencies
import pandas as pd
import sqlalchemy
import numpy as np

# %%
# Import Spotify Data
spotify_data = "spotifyWeeklyTop200Streams_cleaned12.6.csv"

spotify_df = pd.read_csv(spotify_data)
spotify_df.head(50)
# Out:
#     Unnamed: 0                                Name  \
# 0            0                      In My Feelings
# 1            1                        Lucid Dreams
# 2            2                             Nonstop
# 3            3                      God is a woman
# 4            4                                SAD!
# 5            5                              Taste
# 6            6                  Don't Matter To Me
# 7            7                           I Like It
# 8            8                           Moonlight
# 9            9                     Girls Like You
# 10          10                       Nice For What
# 11          11                          Better Now
# 12          12                    Summertime Magic
# 13          13                          Yes Indeed
# 14          14                           I'm Upset
# 15          15                          God's Plan
# 16          16                            Mob Ties
# 17          17                         Jackie Chan
# 18          18                          Youngblood
# 19          19                             Psycho
# 20          20                            Eastside
# 21          21                              Ocean
# 22          22                      Jocelyn Flores
# 23          23              All Girls Are The Same
# 24          24                             changes
# 25          25                             APESHIT
# 26          26                         Look Alive
# 27          27                            Boo'd Up
# 28          28                no tears left to cry
# 29          29                                Bed
# 30          30                          Fuck Love
# 31          31                            All Mine
# 32          32                             Wasted
# 33          33                           rockstar
# 34          34                         Back To You
# 35          35                         Emotionless
# 36          36                  Hopeless Romantic
# 37          37                     Praise The Lord
# 38          38                           One Kiss
# 39          39                   Can't Take A Joke
# 40          40                             Elevate
# 41          41                               Solo
# 42          42                            Big Bank
# 43          43                        Ball For Me
# 44          44                             lovely
# 45          45                                Body
# 46          46                           Plug Walk
# 47          47                              Fr Fr
# 48          48                     Te Boté - Remix
# 49          49  Everybody Dies In Their Nightmares
#
#                           Artist       Features   Streams       Week
# 0                          Drake            NaN  30747676  7/20/2018
# 1                     Juice WRLD            NaN  12930705  7/20/2018
# 2                          Drake            NaN  12312859  7/20/2018
# 3                  Ariana Grande            NaN  10771324  7/20/2018
# 4                   XXXTENTACION            NaN  10503061  7/20/2018
# 5                           Tyga         Offset   9777479  7/20/2018
# 6                          Drake            NaN   9769263  7/20/2018
# 7                        Cardi B            NaN   9278476  7/20/2018
# 8                   XXXTENTACION            NaN   8544143  7/20/2018
# 9                       Maroon 5        Cardi B   8257586  7/20/2018
# 10                         Drake            NaN   8193242  7/20/2018
# 11                   Post Malone            NaN   7877292  7/20/2018
# 12              Childish Gambino            NaN   7519515  7/20/2018
# 13               Lil Baby, Drake            NaN   7436762  7/20/2018
# 14                         Drake            NaN   7313974  7/20/2018
# 15                         Drake            NaN   6886838  7/20/2018
# 16                         Drake            NaN   6010125  7/20/2018
# 17                 Tiesto, Dzeko            NaN   5589022  7/20/2018
# 18           5 Seconds of Summer            NaN   5476526  7/20/2018
# 19                   Post Malone  Ty Dolla $ign   5461822  7/20/2018
# 20  benny blanco, Halsey, Khalid            NaN   5325080  7/20/2018
# 21                 Martin Garrix         Khalid   5277329  7/20/2018
# 22                  XXXTENTACION            NaN   5145261  7/20/2018
# 23                    Juice WRLD            NaN   5073925  7/20/2018
# 24                  XXXTENTACION            NaN   5023686  7/20/2018
# 25                   The Carters            NaN   4830730  7/20/2018
# 26                    BlocBoy JB          Drake   4826668  7/20/2018
# 27                      Ella Mai            NaN   4748460  7/20/2018
# 28                 Ariana Grande            NaN   4509464  7/20/2018
# 29                   Nicki Minaj  Ariana Grande   4444780  7/20/2018
# 30                  XXXTENTACION   Trippie Redd   4353823  7/20/2018
# 31                    Kanye West            NaN   4347034  7/20/2018
# 32                    Juice WRLD   Lil Uzi Vert   4274567  7/20/2018
# 33                   Post Malone      21 Savage   4206779  7/20/2018
# 34                  Selena Gomez            NaN   4172502  7/20/2018
# 35                         Drake            NaN   4156072  7/20/2018
# 36                   Wiz Khalifa       Swae Lee   4128303  7/20/2018
# 37                    A$AP Rocky         Skepta   4095518  7/20/2018
# 38       Calvin Harris, Dua Lipa            NaN   3965186  7/20/2018
# 39                         Drake            NaN   3811354  7/20/2018
# 40                         Drake            NaN   3793839  7/20/2018
# 41                  Clean Bandit    Demi Lovato   3679662  7/20/2018
# 42                            YG            NaN   3663897  7/20/2018
# 43                   Post Malone    Nicki Minaj   3631354  7/20/2018
# 44         Billie Eilish, Khalid            NaN   3597219  7/20/2018
# 45                   Loud Luxury            NaN   3551924  7/20/2018
# 46                  Rich The Kid            NaN   3444255  7/20/2018
# 47                   Wiz Khalifa      Lil Skies   3377195  7/20/2018
# 48                    Nio Garcia            NaN   3376696  7/20/2018
# 49                  XXXTENTACION            NaN   3345149  7/20/2018

# %%
# Drop Features Column in Spotify DataFrame
spotify_df = spotify_df.drop(columns = ['Features', 'Unnamed: 0'])
spotify_df.head()
# Out:
#              Name         Artist   Streams       Week
# 0  In My Feelings          Drake  30747676  7/20/2018
# 1    Lucid Dreams     Juice WRLD  12930705  7/20/2018
# 2         Nonstop          Drake  12312859  7/20/2018
# 3  God is a woman  Ariana Grande  10771324  7/20/2018
# 4            SAD!   XXXTENTACION  10503061  7/20/2018

# %%
# Adjust the Spotify DataFrame so the start of each week lines up with Billboard
from datetime import timedelta
spotify_df["Week"] = pd.to_datetime(spotify_df["Week"])
spotify_df["one_day_behind"] = spotify_df["Week"].apply(lambda x: x - timedelta(days=1))
spotify_df["one_day_behind"] = spotify_df["one_day_behind"].dt.strftime("%m/%d/%y")
spotify_df = spotify_df.drop(columns = ["Week"])
spotify_df.head()
# Out:
#              Name         Artist   Streams one_day_behind
# 0  In My Feelings          Drake  30747676       07/19/18
# 1    Lucid Dreams     Juice WRLD  12930705       07/19/18
# 2         Nonstop          Drake  12312859       07/19/18
# 3  God is a woman  Ariana Grande  10771324       07/19/18
# 4            SAD!   XXXTENTACION  10503061       07/19/18

# %%
# Rename "one_day_"
spotify_df.rename(columns = {'Name': 'Song Name',
                             'Streams': 'Weekly Streams',
                             'one_day_behind': 'Week of'}, inplace = True)
spotify_df.head()
# Out:
#         Song Name         Artist  Weekly Streams   Week of
# 0  In My Feelings          Drake        30747676  07/19/18
# 1    Lucid Dreams     Juice WRLD        12930705  07/19/18
# 2         Nonstop          Drake        12312859  07/19/18
# 3  God is a woman  Ariana Grande        10771324  07/19/18
# 4            SAD!   XXXTENTACION        10503061  07/19/18

# %%
# Import the data from Billboard
billboard_data = "billboardHot100_1999-2019_cleaned_12.6.csv"

billboard_df = pd.read_csv(billboard_data)
billboard_df.head()
# Out:
#   Artists Name  Weekly.rank  Peak.position  Weeks.on.chart      Week  \
# 0      17   NC           41            NaN             NaN  08/18/18
# 1     800    1           45            3.0            42.0  02/24/18
# 2     800    1           40            3.0            41.0  02/17/18
# 3     800    1           33            3.0            40.0  02/10/18
# 4     800    1           46            3.0            39.0  02/03/18
#
#         Date                       Genre  \
# 0   8/3/2018                    Trap,Rap
# 1  4/28/2017  Hip-Hop,Canada,DMV,Pop,Rap
# 2  4/28/2017  Hip-Hop,Canada,DMV,Pop,Rap
# 3  4/28/2017  Hip-Hop,Canada,DMV,Pop,Rap
# 4  4/28/2017  Hip-Hop,Canada,DMV,Pop,Rap
#
#                                      Writing.Credits  \
# 0  Ryan meyer, Rich meyer, Johnny stevens, Allen ...
# 1  Dylan wiggins, Andrew taggart, 6ix, Alessia ca...
# 2  Dylan wiggins, Andrew taggart, 6ix, Alessia ca...
# 3  Dylan wiggins, Andrew taggart, 6ix, Alessia ca...
# 4  Dylan wiggins, Andrew taggart, 6ix, Alessia ca...
#
#                                               Lyrics Features
# 0  NC-17 \nOoh\nMe and my bitch, I swear we like ...      NaN
# 1  1-800-273-8255 \nI've been on the low\nI been ...      NaN
# 2  1-800-273-8255 \nI've been on the low\nI been ...      NaN
# 3  1-800-273-8255 \nI've been on the low\nI been ...      NaN
# 4  1-800-273-8255 \nI've been on the low\nI been ...      NaN

# %%
# Clean the Billboard DataFrame
billboard_df = billboard_df.drop(columns = ['Peak.position', 
                                            'Weeks.on.chart', 
                                            'Date', 
                                            'Writing.Credits', 
                                            'Lyrics', 
                                            'Features'])
billboard_df.head()
# Out:
#   Artists Name  Weekly.rank      Week                       Genre
# 0      17   NC           41  08/18/18                    Trap,Rap
# 1     800    1           45  02/24/18  Hip-Hop,Canada,DMV,Pop,Rap
# 2     800    1           40  02/17/18  Hip-Hop,Canada,DMV,Pop,Rap
# 3     800    1           33  02/10/18  Hip-Hop,Canada,DMV,Pop,Rap
# 4     800    1           46  02/03/18  Hip-Hop,Canada,DMV,Pop,Rap

# %%
# Rename columns in Clean Billboard DataFrame
billboard_df.rename(columns = {'Artists': 'Artist',
                                'Name': 'Song Name', 
                               'Weekly.rank': 'Weekly Rank', 
                               'Week': 'Week of'}, inplace = True )
billboard_df.head()
# Out:
#   Artist Song Name  Weekly Rank   Week of                       Genre
# 0     17        NC           41  08/18/18                    Trap,Rap
# 1    800         1           45  02/24/18  Hip-Hop,Canada,DMV,Pop,Rap
# 2    800         1           40  02/17/18  Hip-Hop,Canada,DMV,Pop,Rap
# 3    800         1           33  02/10/18  Hip-Hop,Canada,DMV,Pop,Rap
# 4    800         1           46  02/03/18  Hip-Hop,Canada,DMV,Pop,Rap

# %%
spotify_df.head()
# Out:
#         Song Name         Artist  Weekly Streams   Week of
# 0  In My Feelings          Drake        30747676  07/19/18
# 1    Lucid Dreams     Juice WRLD        12930705  07/19/18
# 2         Nonstop          Drake        12312859  07/19/18
# 3  God is a woman  Ariana Grande        10771324  07/19/18
# 4            SAD!   XXXTENTACION        10503061  07/19/18

# %%
billboard_df['Artist'] = billboard_df['Artist'].str.rstrip()
billboard_df['Song Name'] = billboard_df['Song Name'].str.rstrip()

# %% [markdown]
# <b> Merging and Billboard and Spotify DataFrames</b>

# %%
df_merged = billboard_df.merge(spotify_df, on = ["Artist"], how = 'left')
df_merged
# Out:
#                        Artist_x   Song Name  Weekly Rank   Week of  \
# 0                            17          NC           41  08/18/18
# 1                           800           1           45  02/24/18
# 2                           800           1           40  02/17/18
# 3                           800           1           33  02/10/18
# 4                           800           1           46  02/03/18
# ...                         ...         ...          ...       ...
# 13277  Zedd, Maren Morris, Grey  The Middle           11  03/10/18
# 13278  Zedd, Maren Morris, Grey  The Middle           13  03/03/18
# 13279  Zedd, Maren Morris, Grey  The Middle           17  02/24/18
# 13280  Zedd, Maren Morris, Grey  The Middle           22  02/17/18
# 13281  Zedd, Maren Morris, Grey  The Middle           23  02/10/18
#
#                                               Genre Artist_y  Weekly Streams
# 0                                          Trap,Rap      NaN             NaN
# 1                        Hip-Hop,Canada,DMV,Pop,Rap      NaN             NaN
# 2                        Hip-Hop,Canada,DMV,Pop,Rap      NaN             NaN
# 3                        Hip-Hop,Canada,DMV,Pop,Rap      NaN             NaN
# 4                        Hip-Hop,Canada,DMV,Pop,Rap      NaN             NaN
# ...                                             ...      ...             ...
# 13277  Deutschland,Electro-Pop,Electronic,Dance,Pop      NaN             NaN
# 13278  Deutschland,Electro-Pop,Electronic,Dance,Pop      NaN             NaN
# 13279  Deutschland,Electro-Pop,Electronic,Dance,Pop      NaN             NaN
# 13280  Deutschland,Electro-Pop,Electronic,Dance,Pop      NaN             NaN
# 13281  Deutschland,Electro-Pop,Electronic,Dance,Pop      NaN             NaN
#
# [13282 rows x 7 columns]

# %%
# SQL
from sqlalchemy import create_engine
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
connection_string = "postgres:postgres@localhost:5432/music_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['billboard6']

# %%
engine.execute("SELECT * FROM billboard6")

# %%
# session = Session(bind=engine)
# songs = session.query(billboard6)
# for song in songs:
#     print(song.song_names)
